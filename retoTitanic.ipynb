# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanVaTe/JuanVaTe/blob/main/retoTitanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reto Titanic

# %% [markdown]
# ## Parte 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "/content/drive/Shareddrives/Reto Titanic/Datasets/"
df_test = pd.read_csv(path + "test.csv")
df_train = pd.read_csv(path + "train.csv")
df_gender = pd.read_csv(path + "gender_submission.csv")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
total = df_train.isnull().sum().sort_values(ascending=False)
percent_1 = df_train.isnull().sum() / df_train.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head()
# Out:
#              Total     %
# Cabin          687  77.1
# Age            177  19.9
# Embarked         2   0.2
# PassengerId      0   0.0
# Survived         0   0.0

# %%
df_train.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
corr = df_test.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5ca4e_row0_col0, #T_5ca4e_row1_col1, #T_5ca4e_row2_col2, #T_5ca4e_row3_col3, #T_5ca4e_row4_col4, #T_5ca4e_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5ca4e_row0_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5ca4e_row0_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_5ca4e_row0_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_5ca4e_row0_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_5ca4e_row0_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_5ca4e_row1_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_5ca4e_row1_col2, #T_5ca4e_row1_col5, #T_5ca4e_row2_col0, #T_5ca4e_row2_col3, #T_5ca4e_row2_col4, #T_5ca4e_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5ca4e_row1_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_5ca4e_row1_col4, #T_5ca4e_row4_col0 {
# ...

# %%
corr = df_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b17f0_row0_col0, #T_b17f0_row1_col1, #T_b17f0_row2_col2, #T_b17f0_row3_col3, #T_b17f0_row4_col4, #T_b17f0_row5_col5, #T_b17f0_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b17f0_row0_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b17f0_row0_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b17f0_row0_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b17f0_row0_col4, #T_b17f0_row3_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b17f0_row0_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b17f0_row0_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b17f0_row1_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_b17f0_row1_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b17f0_row1_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b17f0_row1_col4 {
#   background-color: #7ea1fa;
# ...

# %%
df_test.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.026751 -0.034102  0.003818  0.043080  0.008211
# Pclass         -0.026751  1.000000 -0.492143  0.001087  0.018721 -0.577147
# Age            -0.034102 -0.492143  1.000000 -0.091587 -0.061249  0.337932
# SibSp           0.003818  0.001087 -0.091587  1.000000  0.306895  0.171539
# Parch           0.043080  0.018721 -0.061249  0.306895  1.000000  0.230046
# Fare            0.008211 -0.577147  0.337932  0.171539  0.230046  1.000000

# %%
# Correlation matrix heat map
plt.rcParams["figure.figsize"] = [10, 10]
plt.rcParams["figure.autolayout"] = True
plt.figure()
plt.matshow(corr, cmap = 'GnBu')
plt.colorbar(label="Correlation Matrix Heatmap abs", orientation="horizontal")
plt.show()

# %%
df_test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_gender
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
survived = 'Survived'
not_survived = 'Not Survived'

fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))

women = df_train[df_train['Sex']=='female']
men = df_train[df_train['Sex']=='male']

ax = sns.distplot(women[women['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde =False)
ax = sns.distplot(women[women['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[0], kde =False)
ax.legend()
ax.set_title('Female')

ax = sns.distplot(men[men['Survived'] == 1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(men[men['Survived'] == 0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)
ax.legend()
_ = ax.set_title('Male')
